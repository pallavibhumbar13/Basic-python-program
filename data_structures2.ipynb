# %%
#convert list into set

# %%
nums = [1,2,3,4]

# %%
set(nums)
# Out:
# {1, 2, 3, 4}

# %%
#finding intersection

# %%
a={1,2,3}
b={2,3,4}

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
#using &

# %%
a & b
# Out:
# {2, 3}

# %%
a={1,2,3}

# %%
#copying set

# %%
b=a.copy()

# %%
b
# Out:
# {1, 2, 3}

# %%
#nested sets using frozenset()
#normal sets cannot contains sets
#use frozen sets for nested set

# %%
a= frozenset({1,2,})

# %%
b = {a,3}

# %%
b
# Out:
# {3, frozenset({1, 2})}

# %%
type(b)
# Out:
# set

# %%
type(a)
# Out:
# frozenset

# %%
x=frozenset({1,2})

# %%
y={x,3,4}

# %%
y
# Out:
# {3, 4, frozenset({1, 2})}

# %%
#dictionary

# %%
#creating dictionary

# %%
student = {
    "name":"pallavi",
    "age":18,
    "class":"syit"
}

# %%
type(student)
# Out:
# dict

# %%
print(student)
# Out:
# {'name': 'pallavi', 'age': 18, 'class': 'syit'}

# %%
flowers ={
    "red":"rose",
    "yellow":"sunflower",
    "pink":"lotus"
}

# %%
flowers
# Out:
# {'red': 'rose', 'yellow': 'sunflower', 'pink': 'lotus'}

# %%
fruits = {
    "red":"apple",
    "orange":"orange",
    "green":"watermelon"
}

# %%
fruits
# Out:
# {'red': 'apple', 'orange': 'orange', 'green': 'watermelon'}

# %%
dic = {
    1:"pallavi",
    2:"tanishka",
    3:"sayali",
    4:"bhagyashri"
}

# %%
dic
# Out:
# {1: 'pallavi', 2: 'tanishka', 3: 'sayali', 4: 'bhagyashri'}

# %%
#mixed datatype

# %%
mixed={
    1:"one",
    "name":"pallavi",
     True:100
}

# %%
mixed
# Out:
# {1: 100, 'name': 'pallavi'}

# %%
m={
    3:"one",
    "name":"pallavi",
     True:100
}

# %%
m
# Out:
# {3: 'one', 'name': 'pallavi', True: 100}

# %%
#accessing using key

# %%
student["name"]
# Out:
# 'pallavi'

# %%
student["age"]
# Out:
# 18

# %%
#accessing using get

# %%
student.get("age")
# Out:
# 18

# %%
#adding elements
#add new key value pair

# %%
student["sub"]="python"

# %%
student
# Out:
# {'name': 'pallavi', 'age': 18, 'class': 'syit', 'sub': 'python'}

# %%
student["marks"]=89

# %%
student
# Out:
# {'name': 'pallavi', 'age': 18, 'class': 'syit', 'sub': 'python', 'marks': 89}

# %%
#modifying values

# %%
student["age"]=17

# %%
student
# Out:
# {'name': 'pallavi', 'age': 17, 'class': 'syit', 'sub': 'python', 'marks': 89}

# %%
student["name"]="PALLAVI"

# %%
student
# Out:
# {'name': 'PALLAVI', 'age': 17, 'class': 'syit', 'sub': 'python', 'marks': 89}

# %%
#removing values

# %%
student.pop("class")
# Out:
# 'syit'

# %%
student
# Out:
# {'name': 'PALLAVI', 'age': 17, 'sub': 'python', 'marks': 89}

# %%
#remove last inserted item

# %%
student.popitem()
# Out:
# ('marks', 89)

# %%
student
# Out:
# {'name': 'PALLAVI', 'age': 17, 'sub': 'python'}

# %%
#deleting using del

# %%
del student["age"]

# %%
student
# Out:
# {'name': 'PALLAVI', 'sub': 'python'}

# %%
#remove all elements

# %%
student.clear()

# %%
student
# Out:
# {}

# %%
student1 = {
    "name":"pallavi",
    "age":18,
    "class":"syit"
}

# %%
student1
# Out:
# {'name': 'pallavi', 'age': 18, 'class': 'syit'}

# %%
#finding length

# %%
len(student1)
# Out:
# 3

# %%
#checking keys

# %%
"age" in student1
# Out:
# True

# %%
"sub" in student1
# Out:
# False

# %%
for key in student1:
    key
    print(key)
# Out:
# name
# age
# class

# %%
for value in student1.values():
    value
    print(value)
# Out:
# pallavi
# 18
# syit

# %%
for items in student1.items():
    items
    print(items)
# Out:
# ('name', 'pallavi')
# ('age', 18)
# ('class', 'syit')

# %%
#dictionary keys

# %%
student1.keys()
# Out:
# dict_keys(['name', 'age', 'class'])

# %%
student1.values()
# Out:
# dict_values(['pallavi', 18, 'syit'])

# %%
student1.items()
# Out:
# dict_items([('name', 'pallavi'), ('age', 18), ('class', 'syit')])

# %%
s1=student.copy()

# %%
s1
# Out:
# {'name': 'pallavi', 'age': 18, 'class': 'syit'}

# %%
#nested dictionary

# %%
students = {
    "st1":{
        "name":"pallavi",
        "age":17
    },
    "st2":{
        "name":"ishuuu",
        "age":10
    }
}

# %%
#access nested values

# %%
students["st1"]["name"]
# Out:
# 'pallavi'

# %%
students["st2"]["name"]
# Out:
# 'ishuuu'

# %%
#get method

# %%
student={
    "name":"pallavi",
    "age":17,
    "course":"python"
}

# %%
student
# Out:
# {'name': 'pallavi', 'age': 17, 'course': 'python'}

# %%
student["name"]
# Out:
# 'pallavi'

# %%
student["age"]
# Out:
# 17

# %%
student["course"]
# Out:
# 'python'

# %%
for value in student.values():
    value
    print(value)
# Out:
# pallavi
# 17
# python

# %%
student["marks"]=90

# %%
student
# Out:
# {'name': 'pallavi', 'age': 17, 'course': 'python', 'marks': 90}

# %%
student["marks"]=87

# %%
student
# Out:
# {'name': 'pallavi', 'age': 17, 'course': 'python', 'marks': 87}

# %%
del student["marks"]

# %%
student
# Out:
# {'name': 'pallavi', 'age': 17, 'course': 'python'}

# %%
for items in student.items():
    items
    print(items)
# Out:
# ('name', 'pallavi')
# ('age', 17)
# ('course', 'python')
