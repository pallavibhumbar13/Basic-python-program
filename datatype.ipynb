# %%
#Integer

# %%
#Integer means whole number

# %%
age=21

# %%
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
marks=90

# %%
print(marks,type(marks))
# Out:
# 90 <class 'int'>

# %%
tempreture=-5

# %%
print(tempreture,type(tempreture))
# Out:
# -5 <class 'int'>

# %%
#Integer Operations

# %%
a = 25
b = 30

# %%
#addition

# %%
a+b
# Out:
# 55

# %%
#subtraction

# %%
a-b
# Out:
# -5

# %%
#multiplication

# %%
a*b
# Out:
# 750

# %%
#division

# %%
a/b
# Out:
# 0.8333333333333334

# %%
#floor division

# %%
a//b
# Out:
# 0

# %%
#reminder

# %%
a%b
# Out:
# 25

# %%
#power

# %%
a**b
# Out:
# 867361737988403547205962240695953369140625

# %%
#float

# %%
#float means decimal number

# %%
a=10.34
b=87.76

# %%
a+b
# Out:
# 98.10000000000001

# %%
#string

# %%
#string means text

# %%
first_name ="pallavi"
last_name="bhumbar"
course="python"

# %%
print("first name:",type(first_name))
# Out:
# first name: <class 'str'>

# %%
print(type(last_name))
# Out:
# <class 'str'>

# %%
print("course:",type(course))
# Out:
# course: <class 'str'>

# %%
#string concatention

# %%
f_name ="pallavi"
last_name="bhumbar"

# %%
first_name="pallavi"
last_name="bhumbar"

# %%
full_name=first_name+" "+last_name

# %%
full_name
# Out:
# 'pallavi bhumbar'

# %%
#string repetition

# %%
word = "python "

# %%
print(word*3)
# Out:
# pythonpythonpython

# %%
word = "python "

# %%
print(word*3)
# Out:
# python python python

# %%
#string indexing

# %%
language="python"

# %%
language[0]
# Out:
# 'p'

# %%
language[-1]
# Out:
# 'n'

# %%
language[1]
# Out:
# 'y'

# %%
language[-2]
# Out:
# 'o'

# %%
#string slicing

# %%
language = "python programming"

# %%
language[0:6]
# Out:
# 'python'

# %%
language[7:18]
# Out:
# 'programming'

# %%
language[1:7]
# Out:
# 'ython '

# %%
language[:7]
# Out:
# 'python '

# %%
language[:11]
# Out:
# 'python prog'

# %%
language[-4]
# Out:
# 'm'

# %%
language[7:]
# Out:
# 'programming'

# %%
language[4:]
# Out:
# 'on programming'

# %%
#string method

# %%
message="welcome to python programming"

# %%
message.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
message.lower()
# Out:
# 'welcome to python programming'

# %%
message.title()
# Out:
# 'Welcome To Python Programming'

# %%
message.capitalize()
# Out:
# 'Welcome to python programming'

# %%
len(message)
# Out:
# 29

# %%
#replace
#used to replace a word or character in a string

# %%
text = "i like java"

# %%
new_text=text.replace("java","python")

# %%
print(new_text)
# Out:
# i like python

# %%
text = "i like drawing"

# %%
new_text=text.replace("drawing","coading")

# %%
print(new_text)
# Out:
# i like coading

# %%
#split
#used to split the string into a list

# %%
fruits = "apple,banana,mango"

result = fruits.split(",")

print(result)
# Out:
# ['apple', 'banana', 'mango']

# %%
#join
#Used to join list items into a single string.

# %%
words=['python','is','easy']

# %%
sentence=" ".join(words)

# %%
print(sentence)
# Out:
# python is easy

# %%
words=['sayali','is','girl']

# %%
sentence=" ".join(words)

# %%
print(sentence)
# Out:
# sayali is girl

# %%
#strip
#used to remove extra spaces from the begining and end of string

# %%
text = "  python   "

# %%
clean = text.strip()

# %%
clean
# Out:
# 'python'

# %%
words="   tanishka   "

# %%
clean = words.strip()

# %%
clean
# Out:
# 'tanishka'

# %%
#lstrip remove left strip

# %%
text="  hello"

# %%
text.lstrip()
# Out:
# 'hello'

# %%
#rstrip remove right strip

# %%
text = "hello   "

# %%
text.rstrip()
# Out:
# 'hello'

# %%
text="  hiiiii   "

# %%
text.rstrip()
# Out:
# '  hiiiii'

# %%
#string formatting

# %%
#f-string A modern and easy way to insert variables into strings.

# %%
name = "pallavi"
age = 22

# %%
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is pallavi and I am 22 years old.

# %%
subject1 = "python"
subject2 = "java"

# %%
print(f"I like {subject1} and also {subject2}.")
# Out:
# I like python and also java.

# %%
frnd1="sayali"
frnd2="tanishka"
frnd3="bhagyashri"

# %%
print(f"i have three frnds {frnd1} , {frnd2} and {frnd3} .")
# Out:
# i have three frnds sayali , tanishka and bhagyashri .

# %%
#mathematical operation inside f-string

# %%
a = 10
b = 5

# %%
print(f"sum = {a + b}")
# Out:
# sum = 15

# %%
print(f"mul {a * b}")
# Out:
# mul 50

# %%
print(f"sub {a - b }")
# Out:
# sub 5

# %%
print(f"div {a/b}")
# Out:
# div 2.0

# %%
#format

# %%
name="pallavi"
age=22

# %%
print("My name is {} ans i am {} years old".format(name,age))
# Out:
# My name is pallavi ans i am 22 years old

# %%
sub1="python"
sub2="java"

# %%
print("i like {} and {} ".format(sub1,sub2))
# Out:
# i like python and java

# %%
#boolean
#boolean has only two values:True and False

# %%
is_student = True
is_employee = False

# %%
print(is_student, type(is_student))
# Out:
# True <class 'bool'>

# %%
print(is_employee,type(is_employee))
# Out:
# False <class 'bool'>
