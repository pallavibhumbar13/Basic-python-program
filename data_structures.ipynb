# %%
#data structures
#data structures are used to store and organized data so it can be

# %%
#list
# a list is an ordered , mutable(changeble)collection of items

# %%
nums=[10,20,30,40,50]
print(nums)
# Out:
# [10, 20, 30, 40, 50]

# %%
type(nums)
# Out:
# list

# %%
#tuple
# tuble is an orderedd , immutable(not changeble)collection

# %%
t=(10,20,30,40,50)
print(t)
# Out:
# (10, 20, 30, 40, 50)

# %%
type(t)
# Out:
# tuple

# %%
#set
# a set is unordered collection of unique elements

# %%
s={1,2,3,4,4,5,6,6,6,}
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
type(s)
# Out:
# set

# %%
#dictionary
# a dictionary stores data in key values

# %%
student = {
    "name":"pallavi",
    "age":17
}
print(student)
# Out:
# {'name': 'pallavi', 'age': 17}

# %%
type(student)
# Out:
# dict

# %%
lis = ["lotus","rose","sun-flower","mogara"]
print(lis)
# Out:
# ['lotus', 'rose', 'sun-flower', 'mogara']

# %%
type(lis)
# Out:
# list

# %%
Info = {
    "name":"pallavi",
    "age":17,
    "sub":"python",
    "class":"TYIF"
}
print(Info)
# Out:
# {'name': 'pallavi', 'age': 17, 'sub': 'python', 'class': 'TYIF'}

# %%
type(Info)
# Out:
# dict

# %%
stud = {
    "name":"sayali",
    "age":55,
    "sub":"yedi aahe"
}
print(stud)
# Out:
# {'name': 'sayali', 'age': 55, 'sub': 'yedi aahe'}

# %%
#creating list

# %%
numbers = [1,2,3,4]

# %%
type(numbers)
# Out:
# list

# %%
#empty list

# %%
num = [ ]

# %%
print(num)
# Out:
# []

# %%
#string list

# %%
list=["apple","banana","mango"]

# %%
print(list,type(list))
# Out:
# ['apple', 'banana', 'mango'] <class 'list'>

# %%
#mixed list

# %%
mixed=[1,"pallavi",17.6,True]
print(mixed,type(mixed))
# Out:
# [1, 'pallavi', 17.6, True] <class 'list'>

# %%
#accesing list elements

# %%
fruits =["apple","banana","mango","strawberry","chikuuu"]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-3]
# Out:
# 'mango'

# %%
fruits[3]
# Out:
# 'strawberry'

# %%
fruits[-1]
# Out:
# 'chikuuu'

# %%
#list slicing

# %%
nums = [10,20,30,40,50,60]

# %%
#elements from index 1 to 3

# %%
nums[1:4]
# Out:
# [20, 30, 40]

# %%
nums[0:5]
# Out:
# [10, 20, 30, 40, 50]

# %%
# from begining to index 2

# %%
nums[:3]
# Out:
# [10, 20, 30]

# %%
#from index 2 to end

# %%
nums[2:]
# Out:
# [30, 40, 50, 60]

# %%
#modifying list element

# %%
color =["red","blue","purple","green"]

# %%
#changing element

# %%
color[1] = "yellow"

# %%
print(color)
# Out:
# ['red', 'yellow', 'purple', 'green']

# %%
color[-1]="white"

# %%
print(color)
# Out:
# ['red', 'yellow', 'purple', 'white']

# %%
flower=["lotus","rose","jasmin"]

# %%
flower[2]="sunflower"

# %%
print(flower)
# Out:
# ['lotus', 'rose', 'sunflower']

# %%
#Adding element

# %%
nums=[1,2,3,4]

# %%
# Adding single element at end

# %%
nums.append(5)

# %%
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
#adding element at specific position

# %%
nums.insert(1,23)

# %%
print(nums)
# Out:
# [1, 23, 2, 3, 4, 5]

# %%
nums.insert(4,78)

# %%
print(nums)
# Out:
# [1, 23, 2, 3, 78, 4, 5]

# %%
#adding multiple elements

# %%
nums.extend([6,7])

# %%
print(nums)
# Out:
# [1, 23, 2, 3, 78, 4, 5, 6, 7]

# %%
#removing elements

# %%
nums.remove(78)

# %%
print(nums)
# Out:
# [1, 23, 2, 3, 4, 5, 6, 7]

# %%
nums.remove(4)

# %%
nums
# Out:
# [1, 23, 2, 3, 5, 6, 7]

# %%
nums.pop()
# Out:
# 7

# %%
#delete using index

# %%
del nums[1]

# %%
nums
# Out:
# [1, 2, 3, 5, 6]

# %%
#remove all elements

# %%
nums.clear()

# %%
nums
# Out:
# []

# %%
#length of list

# %%
num1 =[12,23,34,45,56,67]

# %%
len(num1)
# Out:
# 6

# %%
5 in num1
# Out:
# False

# %%
45 in num1
# Out:
# True

# %%
for num1 in (num1):
    print(num1)
# Out:
# 12
# 23
# 34
# 45
# 56
# 67

# %%
nums2=[1,9,4,8,6]

# %%
#sort ascending

# %%
nums2.sort()

# %%
nums2
# Out:
# [1, 4, 6, 8, 9]

# %%
#sort descending

# %%
nums2.sort(reverse=True)

# %%
nums2
# Out:
# [9, 8, 6, 4, 1]

# %%
#reversing list

# %%
nums2.reverse()

# %%
nums2
# Out:
# [1, 4, 6, 8, 9]

# %%
#copying list

# %%
a=[1,2,3,4,5]

# %%
b=a.copy()

# %%
b
# Out:
# [1, 2, 3, 4, 5]

# %%
#joining list

# %%
a=[1,2,3]
b=[4,5,6]

# %%
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#repeat list

# %%
a+a
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a+b*4
# Out:
# [1, 2, 3, 4, 5, 6, 4, 5, 6, 4, 5, 6, 4, 5, 6]

# %%
s=[1,2,3,4,5,5,5,6,7]

# %%
max(s)
# Out:
# 7

# %%
min(s)
# Out:
# 1

# %%
sum(s)
# Out:
# 38

# %%
s.count(5)
# Out:
# 3

# %%
s.index(6)
# Out:
# 7

# %%
#creating tuple

# %%
#empty tuple

# %%
t=()

# %%
t
# Out:
# ()

# %%
#print tuple

# %%
numbers=(12,34,56,78,90)

# %%
numbers
# Out:
# (12, 34, 56, 78, 90)

# %%
#string tuple

# %%
t2=("apple","banana","mango")

# %%
t2
# Out:
# ('apple', 'banana', 'mango')

# %%
# mixed tuple

# %%
mixedt=(1,"pallavi",90.98,True)

# %%
mixedt
# Out:
# (1, 'pallavi', 90.98, True)

# %%
# accessing element of tuple

# %%
mixedt[0]
# Out:
# 1

# %%
mixedt[-1]
# Out:
# True

# %%
mixedt[-3]
# Out:
# 'pallavi'

# %%
numbers[0:4]
# Out:
# (12, 34, 56, 78)

# %%
numbers[1:4]
# Out:
# (34, 56, 78)

# %%
numbers[:3]
# Out:
# (12, 34, 56)

# %%
# length of tuple

# %%
len(numbers)
# Out:
# 5

# %%
#checking element is present or not

# %%
9 in numbers
# Out:
# False

# %%
34 in numbers
# Out:
# True

# %%
for numbers in (numbers):
    print(numbers)
# Out:
# 12
# 34
# 56
# 78
# 90

# %%
#joining list

# %%
a=(1,2,3)
b=(4,5,6)

# %%
a
# Out:
# (1, 2, 3)

# %%
b
# Out:
# (4, 5, 6)

# %%
a+b
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#repeat list

# %%
a*2
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
a*5
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
#common methods

# %%
tup=(90,7,6,9,32)

# %%
tup
# Out:
# (90, 7, 6, 9, 32)

# %%
max(tup)
# Out:
# 90

# %%
min(tup)
# Out:
# 6

# %%
sum(tup)
# Out:
# 144

# %%
#convert list into tuple

# %%
li1=[13,45,56,7,8]

# %%
li1
# Out:
# [13, 45, 56, 7, 8]

# %%
tuple(li1)
# Out:
# (13, 45, 56, 7, 8)

# %%
#printing single element in tuple

# %%
single = (10,)

# %%
print(single,type(single))
# Out:
# (10,) <class 'tuple'>

# %%
single1 =(10)

# %%
print(single1,type(single1))
# Out:
# 10 <class 'int'>

# %%
#tuple unpacking

# %%
nums=(1,2,3)

# %%
#unpacking values

# %%
a,b,c = nums

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
nums=("fruits","flower","roses","apples")

# %%
a,b,c,d=nums

# %%
a
# Out:
# 'fruits'

# %%
b
# Out:
# 'flower'

# %%
c
# Out:
# 'roses'

# %%
d
# Out:
# 'apples'

# %%
#simple string methods

# %%
p="welcome to python programming"

# %%
p
# Out:
# 'welcome to python programming'

# %%
p.upper()
# Out:
# 'WELCOME TO PYTHON PROGRAMMING'

# %%
p.lower()
# Out:
# 'welcome to python programming'

# %%
p.title()
# Out:
# 'Welcome To Python Programming'

# %%
len(p)
# Out:
# 29

# %%
print("welcome \n to \n python \n programming \n ")
# Out:
# welcome
#  to
#  python
#  programming

# %%
#set

# %%
#printing set

# %%
s1={12,34,4,6,7,8}

# %%
s1
# Out:
# {4, 6, 7, 8, 12, 34}

# %%
type(s1)
# Out:
# set

# %%
#empty set

# %%
s2 = {}

# %%
s2
# Out:
# {}

# %%
s3={1,2,3,4,1,2,1,1,1,7}

# %%
s3
# Out:
# {1, 2, 3, 4, 7}

# %%
#add element in set

# %%
s3.add(8)

# %%
s3
# Out:
# {1, 2, 3, 4, 7, 8}

# %%
#add multiple element in set

# %%
s3.update([23,56,67,90])

# %%
s3
# Out:
# {1, 2, 3, 4, 7, 8, 23, 56, 67, 90}

# %%
#remove element in set

# %%
s3.remove(67)

# %%
s3
# Out:
# {1, 2, 3, 4, 7, 8, 23, 56, 90}

# %%
# remove element using pop

# %%
s3.pop()
# Out:
# 1

# %%
s3.pop()
# Out:
# 2

# %%
s3.discard(23)

# %%
s3
# Out:
# {3, 4, 7, 8, 56, 90}

# %%
# clear method used to clear all elements in list

# %%
s3.clear()

# %%
s3
# Out:
# set()

# %%
s4={13,4,26,9,8,24}

# %%
s4
# Out:
# {4, 8, 9, 13, 24, 26}

# %%
#length of set

# %%
len(s4)
# Out:
# 6

# %%
#checking element is present or not

# %%
99 in s4
# Out:
# False

# %%
for s4 in (s4):
    print(s4)
# Out:
# 4
# 8
# 9
# 26
# 13
# 24

# %%
#mixed set

# %%
s5={1,13.5,"string",True}

# %%
s5
# Out:
# {1, 13.5, 'string'}

# %%
s6={3,13.5,"string",True}

# %%
s6
# Out:
# {13.5, 3, True, 'string'}

# %%
a={1,2}
b={3,4}

# %%
#joining list

# %%
a
# Out:
# {1, 2}

# %%
b
# Out:
# {3, 4}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a1={1,2,3}
b1={2,3,4}

# %%
a1
# Out:
# {1, 2, 3}

# %%
b1
# Out:
# {2, 3, 4}

# %%
a1-b1
# Out:
# {1}

# %%
a1.difference(b1)
# Out:
# {1}

# %%
a1.symmetric_difference(b1)
# Out:
# {1, 4}

# %%
#common methods

# %%
nums = {12,34,56,43,76}

# %%
max(nums)
# Out:
# 76

# %%
min(nums)
# Out:
# 12

# %%
sum(nums)
# Out:
# 221
