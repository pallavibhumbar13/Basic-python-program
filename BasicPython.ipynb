# %%
# variables

# %%
# A variables is name to store data

# %%
my_name="pallavi"

# %%
print(my_name)
# Out:
# pallavi

# %%
student_age=17

# %%
print(student_age)
# Out:
# 17

# %%
my_marks=90.87

# %%
print(my_marks)
# Out:
# 90.87

# %%
my_name="pallavi"

# %%
print("Name",my_name)
# Out:
# Name pallavi

# %%
#printing age

# %%
my_age=18

# %%
print("Age:",my_age)
# Out:
# Age: 18

# %%
my_city="pune"

# %%
print("CITY:",my_city)
# Out:
# CITY: pune

# %%
course="python"

# %%
print("before changing:",course)
# Out:
# before changing: python

# %%
course="java"

# %%
print("after changing:",course)
# Out:
# after changing: java

# %%
#multiple values assign

# %%
x,y,z = 100,200,300

# %%
print("x=",x)
# Out:
# x= 100

# %%
print("y=",y)
# Out:
# y= 200

# %%
print("z=",z)
# Out:
# z= 300

# %%
#same value to multiple variables

# %%
maths=science=english=90

# %%
print(maths)
# Out:
# 90

# %%
print("Science:",science)
# Out:
# Science: 90

# %%
print(english)
# Out:
# 90

# %%
#invalid variables

# %%
2name="pallavi"
# Out:
#   Cell In[62], line 1
#     2name="pallavi"
#     ^
# SyntaxError: invalid decimal literal

# %%
student-name="rahul"
# Out:
#   Cell In[63], line 1
#     student-name="rahul"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
full name ="pallavi"
# Out:
#   Cell In[64], line 1
#     full name ="pallavi"
#          ^
# SyntaxError: invalid syntax

# %%
#dynamic typing

# %%
#python automatically understand the data type

# %%
value=10

# %%
print(value)
# Out:
# 10

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
sub="python"

# %%
print(sub)
# Out:
# python

# %%
print(type(sub))
# Out:
# <class 'str'>

# %%
marks=90.80

# %%
print(marks)
# Out:
# 90.8

# %%
print(type(marks))
# Out:
# <class 'float'>

# %%
value=10

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
#input example

# %%
name = input("enter your name: ")
# Out:
# enter your name:  pallavi

# %%
print("name:",name)
# Out:
# name: pallavi

# %%
age = input("enter your age:")
# Out:
# enter your age: 17

# %%
print("age:",age)
# Out:
# age: 17

# %%
cast = input("enter your cast")
# Out:
# enter your cast maratha

# %%
print("cast:",cast)
# Out:
# cast: maratha

# %%
age = int(input("enter your age:"))
# Out:
# enter your age: 17

# %%
print("age",age)
# Out:
# age 17

# %%
marks = int(input("enter your marks:"))
print(marks)
# Out:
# enter your marks: 88
# 88

# %%
#common escape characters

# %%
# escape characters are special symbols (starting with \)used to add formating.

# %%
#new line -> \n
#moves text to the next line

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
#tab space -> \t
#adds horizontal space (tab)

# %%
print("Hello\tworld")
# Out:
# Hello	world

# %%
#backslash ->\\

# %%
print("c:\\users\\pallavi")
# Out:
# c:\users\pallavi

# %%
#single quote -> \'
#used when string is inside in a single quote

# %%
print('it\'s python')
# Out:
# it's python

# %%
#double quote ->\"
#used when string is inside in a double quote

# %%
print("i like \"python\"")
# Out:
# i like "python"

# %%
#backspace -> \b
#removes one character before it

# %%
print("hellooo\b")
# Out:
# helloo

# %%
#unicode character

# %%
# a unicode character is a universal encoding system that assign a unique number (code point)
#to every character in every language.

# %%
print("\u0041")
# Out:
# A

# %%
print("\u0939")
# Out:
# ह

# %%
#print() function

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
