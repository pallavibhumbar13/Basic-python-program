# %%
#arithmatic operation

# %%
a=10
b=3

# %%
#addition

# %%
a+b
# Out:
# 13

# %%
#subtraction

# %%
a-b
# Out:
# 7

# %%
#division

# %%
a/b
# Out:
# 3.3333333333333335

# %%
#multiplication

# %%
a*b
# Out:
# 30

# %%
#modulus

# %%
a%b
# Out:
# 1

# %%
#floor division

# %%
a//b
# Out:
# 3

# %%
#comaprison operator

# %%
x=5

y=10

# %%
#equal to

# %%
x == y
# Out:
# False

# %%
#not equal to

# %%
x != y
# Out:
# True

# %%
# greater than

# %%
x > y
# Out:
# False

# %%
#less than

# %%
x < y
# Out:
# True

# %%
#greater than or equal to

# %%
x >= y
# Out:
# False

# %%
#less than or equal to

# %%
x <= y
# Out:
# True

# %%
#logical operators

# %%
#and: returens true only if both conditions are true.
#or: returns true if at one condition are true.
#not: reverse the result,inverting true or false and vise versa.

# %%
a = True
b = False

# %%
# and

# %%
a and b
# Out:
# False

# %%
#or

# %%
a or b
# Out:
# True

# %%
#not

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
#assignment operator

# %%
x = 5

# %%
x=x+5

# %%
print(x)
# Out:
# 10

# %%
x=x-5

# %%
print(x)
# Out:
# 5

# %%
x +=3

# %%
print(x)
# Out:
# 8

# %%
x -=5

# %%
print(x)
# Out:
# 3

# %%
x *=4

# %%
x
# Out:
# 12

# %%
x /=3

# %%
x
# Out:
# 4.0

# %%
#membership operators

# %%
fruits =["apple","banana","mango"]

# %%
"apple" in fruits
# Out:
# True

# %%
"grapes" not in fruits
# Out:
# True

# %%
"banana" not in fruits
# Out:
# False

# %%
#identity operators

# %%
a = [1,2,3]
b = a
c = [1,2,3]

# %%
#true

# %%
a is b
# Out:
# True

# %%
#false

# %%
a is c
# Out:
# False

# %%
b is c
# Out:
# False

# %%
b is a
# Out:
# True

# %%
a is not c
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
b is not c
# Out:
# True
